# %% [markdown]
# <a href="https://colab.research.google.com/github/tsubauaaa/AITrialTraining/blob/main/Training2/AITraining2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Google Driveをマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks
# %cd AITraining/
# %cd yolo
# %cd yolov5
# Out:
# /content/drive/My Drive/Colab Notebooks
# /content/drive/My Drive/Colab Notebooks/AITraining
# /content/drive/My Drive/Colab Notebooks/AITraining/yolo
# /content/drive/My Drive/Colab Notebooks/AITraining/yolo/yolov5

# %%
# %pip install -qr requirements.txt  # install dependencies

# %%
# DataAugmentation degrees: (1, 0.0, 45.0), epochs: 5, batch-size: 16
# !python train_mlflow_hydra.py
# Out:
# {'weights': 'yolov5s.pt', 'cfg': './yolov5x.yaml', 'data': './data.yaml', 'hyp': 'data/hyp.scratch.yaml', 'epochs': 5, 'batch_size': 16, 'img_size': [640, 640], 'world_size': 1, 'global_rank': -1, 'resume': False, 'name': 'test_yolov5x', 'evolve': False, 'project': 'runs/train', 'exist_ok': False, 'save_dir': 'runs/train/exp', 'total_batch_size': 16, 'device': '', 'local_rank': -1, 'single_cls': False, 'adam': False, 'linear_lr': False, 'sync_bn': False, 'cache_images': False, 'rect': False, 'workers': 8, 'image_weights': False, 'quad': False, 'noautoanchor': False, 'multi_scale': False, 'notest': False, 'bucket': '', 'nosave': False}
# github: ⚠️ WARNING: code is out of date by 34 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# [2021-03-22 02:52:07,672][utils.torch_utils][INFO] - YOLOv5 v4.0-104-gefa4946 torch 1.8.0+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# DataAugmentation degrees: (10, 5.0, 0.0), epochs: 5, batch-size: 16
# !python train_mlflow_hydra_da_change.py
# Out:
# {'weights': 'yolov5s.pt', 'cfg': './yolov5x.yaml', 'data': './data.yaml', 'hyp': 'data/hyp.scratch.yaml', 'epochs': 5, 'batch_size': 16, 'img_size': [640, 640], 'world_size': 1, 'global_rank': -1, 'resume': False, 'name': 'test_yolov5x', 'evolve': False, 'project': 'runs/train', 'exist_ok': False, 'save_dir': 'runs/train/exp', 'total_batch_size': 16, 'device': '', 'local_rank': -1, 'single_cls': False, 'adam': False, 'linear_lr': False, 'sync_bn': False, 'cache_images': False, 'rect': False, 'workers': 8, 'image_weights': False, 'quad': False, 'noautoanchor': False, 'multi_scale': False, 'notest': False, 'bucket': '', 'nosave': False}
# github: ⚠️ WARNING: code is out of date by 34 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# [2021-03-22 02:55:26,783][utils.torch_utils][INFO] - YOLOv5 v4.0-104-gefa4946 torch 1.8.0+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# DataAugmentation degrees: (1, 0.0, 45.0), epochs: 5, batch-size: 8, 16
# !python train_mlflow_hydra.py -m batch_size=8,16
# Out:
# [2021-03-22 02:58:50,765][HYDRA] Launching 2 jobs locally
# [2021-03-22 02:58:50,765][HYDRA] 	#0 : batch_size=8
# {'weights': 'yolov5s.pt', 'cfg': './yolov5x.yaml', 'data': './data.yaml', 'hyp': 'data/hyp.scratch.yaml', 'epochs': 5, 'batch_size': 8, 'img_size': [640, 640], 'world_size': 1, 'global_rank': -1, 'resume': False, 'name': 'test_yolov5x', 'evolve': False, 'project': 'runs/train', 'exist_ok': False, 'save_dir': 'runs/train/exp', 'total_batch_size': 16, 'device': '', 'local_rank': -1, 'single_cls': False, 'adam': False, 'linear_lr': False, 'sync_bn': False, 'cache_images': False, 'rect': False, 'workers': 8, 'image_weights': False, 'quad': False, 'noautoanchor': False, 'multi_scale': False, 'notest': False, 'bucket': '', 'nosave': False}
# github: ⚠️ WARNING: code is out of date by 34 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# ...

# %%
# DataAugmentation degrees: (1, 0.0, 45.0), epochs: 5, 10 batch-size: 16
# !python train_mlflow_hydra.py -m epochs=5,10
# Out:
# [2021-03-22 03:05:31,137][HYDRA] Launching 2 jobs locally
# [2021-03-22 03:05:31,137][HYDRA] 	#0 : epochs=5
# {'weights': 'yolov5s.pt', 'cfg': './yolov5x.yaml', 'data': './data.yaml', 'hyp': 'data/hyp.scratch.yaml', 'epochs': 5, 'batch_size': 16, 'img_size': [640, 640], 'world_size': 1, 'global_rank': -1, 'resume': False, 'name': 'test_yolov5x', 'evolve': False, 'project': 'runs/train', 'exist_ok': False, 'save_dir': 'runs/train/exp', 'total_batch_size': 16, 'device': '', 'local_rank': -1, 'single_cls': False, 'adam': False, 'linear_lr': False, 'sync_bn': False, 'cache_images': False, 'rect': False, 'workers': 8, 'image_weights': False, 'quad': False, 'noautoanchor': False, 'multi_scale': False, 'notest': False, 'bucket': '', 'nosave': False}
# github: ⚠️ WARNING: code is out of date by 34 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# ...
