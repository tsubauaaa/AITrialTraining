# %% [markdown]
# <a href="https://colab.research.google.com/github/tsubauaaa/AITrialTraining/blob/main/Training1/AITraining1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Google Driveをマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks
# %cd AITraining/
# %cd yolo
# %cd yolov5
# Out:
# /content/drive/My Drive/Colab Notebooks
# /content/drive/My Drive/Colab Notebooks/AITraining
# /content/drive/My Drive/Colab Notebooks/AITraining/yolo
# /content/drive/My Drive/Colab Notebooks/AITraining/yolo/yolov5

# %%
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/
# Image(filename='runs/detect/exp6/zidane.jpg', width=600)

# %%
# !python train.py --img 640 --batch 16 --epochs 1000 --data data.yaml --cfg yolov5x.yaml --weights yolov5x.pt --nosave --cache --name test_yolov5x
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#                  all          70         140    6.92e-05     0.00595    2.82e-06    1.13e-06
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      2/999     13.6G   0.09951     0.032   0.05346     0.185        19       640: 100% 18/18 [00:26<00:00,  1.45s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:01<00:00,  1.70it/s]
#                  all          70         140    0.000757      0.0932    0.000219    5.12e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      3/999     13.6G   0.08693   0.02982    0.0527    0.1694        50       640: 100% 18/18 [00:25<00:00,  1.39s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 3/3 [00:01<00:00,  1.82it/s]
#                  all          70         140     0.00986       0.201      0.0068     0.00154
#
# ...

# %%
# !python detect.py --weights last.pt --img 640 --conf 0.4 --source data/images/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/', update=False, view_img=False, weights=['last.pt'])
# YOLOv5 v4.0-104-gefa4946 torch 1.7.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87232339 parameters, 0 gradients, 217.2 GFLOPS
# image 1/6 /content/drive/My Drive/Colab Notebooks/AITraining/yolo/yolov5/data/images/bus.jpg: 640x480 Done. (0.044s)
# image 2/6 /content/drive/My Drive/Colab Notebooks/AITraining/yolo/yolov5/data/images/dice-example1.jpg: 640x480 3 6s, Done. (0.035s)
# image 3/6 /content/drive/My Drive/Colab Notebooks/AITraining/yolo/yolov5/data/images/dice-example2.jpg: 640x480 1 6, Done. (0.035s)
# image 4/6 /content/drive/My Drive/Colab Notebooks/AITraining/yolo/yolov5/data/images/dice-example3.jpg: 640x480 Done. (0.034s)
# ...

# %%
Image(filename='runs/detect/exp19/dice-example4.jpg', width=600)
# Image(filename='runs/detect/exp17/dice-example2.jpg', width=600)
# Image(filename='runs/detect/exp17/bus.jpg', width=600)
